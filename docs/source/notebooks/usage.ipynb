# %% [markdown]
# # Tutorial

# %% [markdown]
# In this tutorial, we will explore how to use SWAMP-E to simulate planetary atmospheres.

# %%
import numpy

# %%
# %pip install -i https://test.pypi.org/simple/ SWAMPE==0.0.19
# Out:
# Looking in indexes: https://test.pypi.org/simple/
# Collecting SWAMPE==0.0.19
#   Downloading https://test-files.pythonhosted.org/packages/05/fc/0c7ec39cf71fadb1f328494bacf1797f277b28db2f28863806afaf2b8583/SWAMPE-0.0.19-py3-none-any.whl (36 kB)
# Requirement already satisfied: imageio in c:\users\ek672\appdata\local\continuum\anaconda3\lib\site-packages (from SWAMPE==0.0.19) (2.8.0)
# Requirement already satisfied: matplotlib in c:\users\ek672\appdata\local\continuum\anaconda3\lib\site-packages (from SWAMPE==0.0.19) (3.5.2)
# Requirement already satisfied: numpy in c:\users\ek672\appdata\local\continuum\anaconda3\lib\site-packages (from SWAMPE==0.0.19) (1.19.2)
# Requirement already satisfied: scipy in c:\users\ek672\appdata\local\continuum\anaconda3\lib\site-packages (from SWAMPE==0.0.19) (1.4.1)
# Requirement already satisfied: astropy in c:\users\ek672\appdata\local\continuum\anaconda3\lib\site-packages (from SWAMPE==0.0.19) (4.0.1.post1)
# Requirement already satisfied: pandas in c:\users\ek672\appdata\local\continuum\anaconda3\lib\site-packages (from SWAMPE==0.0.19) (1.0.3)
# Requirement already satisfied: jupyter in c:\users\ek672\appdata\local\continuum\anaconda3\lib\site-packages (from SWAMPE==0.0.19) (1.0.0)
# Requirement already satisfied: pillow in c:\users\ek672\appdata\local\continuum\anaconda3\lib\site-packages (from imageio->SWAMPE==0.0.19) (7.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ek672\appdata\local\continuum\anaconda3\lib\site-packages (from matplotlib->SWAMPE==0.0.19) (2.8.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\ek672\appdata\local\continuum\anaconda3\lib\site-packages (from matplotlib->SWAMPE==0.0.19) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\ek672\appdata\local\continuum\anaconda3\lib\site-packages (from matplotlib->SWAMPE==0.0.19) (0.10.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\ek672\appdata\local\continuum\anaconda3\lib\site-packages (from matplotlib->SWAMPE==0.0.19) (20.3)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\ek672\appdata\local\continuum\anaconda3\lib\site-packages (from matplotlib->SWAMPE==0.0.19) (2.4.7)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ek672\appdata\local\continuum\anaconda3\lib\site-packages (from matplotlib->SWAMPE==0.0.19) (4.33.3)
# Requirement already satisfied: pytz>=2017.2 in c:\users\ek672\appdata\local\continuum\anaconda3\lib\site-packages (from pandas->SWAMPE==0.0.19) (2020.1)
# Requirement already satisfied: qtconsole in c:\users\ek672\appdata\local\continuum\anaconda3\lib\site-packages (from jupyter->SWAMPE==0.0.19) (4.7.4)
# Requirement already satisfied: notebook in c:\users\ek672\appdata\local\continuum\anaconda3\lib\site-packages (from jupyter->SWAMPE==0.0.19) (6.0.3)
# Requirement already satisfied: jupyter-console in c:\users\ek672\appdata\local\continuum\anaconda3\lib\site-packages (from jupyter->SWAMPE==0.0.19) (6.1.0)
# Requirement already satisfied: nbconvert in c:\users\ek672\appdata\local\continuum\anaconda3\lib\site-packages (from jupyter->SWAMPE==0.0.19) (5.6.1)
# Requirement already satisfied: ipywidgets in c:\users\ek672\appdata\local\continuum\anaconda3\lib\site-packages (from jupyter->SWAMPE==0.0.19) (7.5.1)
# Requirement already satisfied: ipykernel in c:\users\ek672\appdata\local\continuum\anaconda3\lib\site-packages (from jupyter->SWAMPE==0.0.19) (5.1.4)
# Requirement already satisfied: six>=1.5 in c:\users\ek672\appdata\local\continuum\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->SWAMPE==0.0.19) (1.14.0)
# Requirement already satisfied: jupyter-client>=4.1 in c:\users\ek672\appdata\local\continuum\anaconda3\lib\site-packages (from qtconsole->jupyter->SWAMPE==0.0.19) (6.1.3)
# Requirement already satisfied: traitlets in c:\users\ek672\appdata\local\continuum\anaconda3\lib\site-packages (from qtconsole->jupyter->SWAMPE==0.0.19) (4.3.3)
# Requirement already satisfied: ipython-genutils in c:\users\ek672\appdata\local\continuum\anaconda3\lib\site-packages (from qtconsole->jupyter->SWAMPE==0.0.19) (0.2.0)
# Requirement already satisfied: pygments in c:\users\ek672\appdata\local\continuum\anaconda3\lib\site-packages (from qtconsole->jupyter->SWAMPE==0.0.19) (2.6.1)
# Requirement already satisfied: qtpy in c:\users\ek672\appdata\local\continuum\anaconda3\lib\site-packages (from qtconsole->jupyter->SWAMPE==0.0.19) (1.9.0)
# Requirement already satisfied: pyzmq>=17.1 in c:\users\ek672\appdata\local\continuum\anaconda3\lib\site-packages (from qtconsole->jupyter->SWAMPE==0.0.19) (18.1.1)
# Requirement already satisfied: jupyter-core in c:\users\ek672\appdata\local\continuum\anaconda3\lib\site-packages (from qtconsole->jupyter->SWAMPE==0.0.19) (4.6.3)
# Requirement already satisfied: Send2Trash in c:\users\ek672\appdata\local\continuum\anaconda3\lib\site-packages (from notebook->jupyter->SWAMPE==0.0.19) (1.5.0)
# Requirement already satisfied: jinja2 in c:\users\ek672\appdata\local\continuum\anaconda3\lib\site-packages (from notebook->jupyter->SWAMPE==0.0.19) (2.11.2)
# Requirement already satisfied: tornado>=5.0 in c:\users\ek672\appdata\local\continuum\anaconda3\lib\site-packages (from notebook->jupyter->SWAMPE==0.0.19) (6.0.4)
# Requirement already satisfied: terminado>=0.8.1 in c:\users\ek672\appdata\local\continuum\anaconda3\lib\site-packages (from notebook->jupyter->SWAMPE==0.0.19) (0.8.3)
# Requirement already satisfied: nbformat in c:\users\ek672\appdata\local\continuum\anaconda3\lib\site-packages (from notebook->jupyter->SWAMPE==0.0.19) (5.0.6)
# Requirement already satisfied: prometheus-client in c:\users\ek672\appdata\local\continuum\anaconda3\lib\site-packages (from notebook->jupyter->SWAMPE==0.0.19) (0.7.1)
# Requirement already satisfied: ipython in c:\users\ek672\appdata\local\continuum\anaconda3\lib\site-packages (from jupyter-console->jupyter->SWAMPE==0.0.19) (7.13.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\ek672\appdata\local\continuum\anaconda3\lib\site-packages (from jupyter-console->jupyter->SWAMPE==0.0.19) (3.0.5)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\ek672\appdata\local\continuum\anaconda3\lib\site-packages (from nbconvert->jupyter->SWAMPE==0.0.19) (0.8.4)
# Requirement already satisfied: defusedxml in c:\users\ek672\appdata\local\continuum\anaconda3\lib\site-packages (from nbconvert->jupyter->SWAMPE==0.0.19) (0.6.0)
# Requirement already satisfied: testpath in c:\users\ek672\appdata\local\continuum\anaconda3\lib\site-packages (from nbconvert->jupyter->SWAMPE==0.0.19) (0.4.4)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\ek672\appdata\local\continuum\anaconda3\lib\site-packages (from nbconvert->jupyter->SWAMPE==0.0.19) (0.3)
# Requirement already satisfied: bleach in c:\users\ek672\appdata\local\continuum\anaconda3\lib\site-packages (from nbconvert->jupyter->SWAMPE==0.0.19) (3.1.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\ek672\appdata\local\continuum\anaconda3\lib\site-packages (from nbconvert->jupyter->SWAMPE==0.0.19) (1.4.2)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\ek672\appdata\local\continuum\anaconda3\lib\site-packages (from ipywidgets->jupyter->SWAMPE==0.0.19) (3.5.1)
# Requirement already satisfied: decorator in c:\users\ek672\appdata\local\continuum\anaconda3\lib\site-packages (from traitlets->qtconsole->jupyter->SWAMPE==0.0.19) (4.4.2)
# Requirement already satisfied: pywin32>=1.0; sys_platform == "win32" in c:\users\ek672\appdata\local\continuum\anaconda3\lib\site-packages (from jupyter-core->qtconsole->jupyter->SWAMPE==0.0.19) (227)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\ek672\appdata\local\continuum\anaconda3\lib\site-packages (from jinja2->notebook->jupyter->SWAMPE==0.0.19) (1.1.1)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\users\ek672\appdata\local\continuum\anaconda3\lib\site-packages (from nbformat->notebook->jupyter->SWAMPE==0.0.19) (3.2.0)
# Requirement already satisfied: jedi>=0.10 in c:\users\ek672\appdata\local\continuum\anaconda3\lib\site-packages (from ipython->jupyter-console->jupyter->SWAMPE==0.0.19) (0.15.2)
# Requirement already satisfied: backcall in c:\users\ek672\appdata\local\continuum\anaconda3\lib\site-packages (from ipython->jupyter-console->jupyter->SWAMPE==0.0.19) (0.1.0)
# Requirement already satisfied: colorama; sys_platform == "win32" in c:\users\ek672\appdata\local\continuum\anaconda3\lib\site-packages (from ipython->jupyter-console->jupyter->SWAMPE==0.0.19) (0.4.3)
# Requirement already satisfied: pickleshare in c:\users\ek672\appdata\local\continuum\anaconda3\lib\site-packages (from ipython->jupyter-console->jupyter->SWAMPE==0.0.19) (0.7.5)
# Requirement already satisfied: setuptools>=18.5 in c:\users\ek672\appdata\local\continuum\anaconda3\lib\site-packages (from ipython->jupyter-console->jupyter->SWAMPE==0.0.19) (46.4.0.post20200518)
# Requirement already satisfied: wcwidth in c:\users\ek672\appdata\local\continuum\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->jupyter-console->jupyter->SWAMPE==0.0.19) (0.1.9)
# Requirement already satisfied: webencodings in c:\users\ek672\appdata\local\continuum\anaconda3\lib\site-packages (from bleach->nbconvert->jupyter->SWAMPE==0.0.19) (0.5.1)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\ek672\appdata\local\continuum\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->notebook->jupyter->SWAMPE==0.0.19) (0.16.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\ek672\appdata\local\continuum\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->notebook->jupyter->SWAMPE==0.0.19) (19.3.0)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in c:\users\ek672\appdata\local\continuum\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->notebook->jupyter->SWAMPE==0.0.19) (4.12.0)
# Requirement already satisfied: parso>=0.5.2 in c:\users\ek672\appdata\local\continuum\anaconda3\lib\site-packages (from jedi>=0.10->ipython->jupyter-console->jupyter->SWAMPE==0.0.19) (0.5.2)
# Requirement already satisfied: typing-extensions>=3.6.4; python_version < "3.8" in c:\users\ek672\appdata\local\continuum\anaconda3\lib\site-packages (from importlib-metadata; python_version < "3.8"->jsonschema!=2.5.0,>=2.4->nbformat->notebook->jupyter->SWAMPE==0.0.19) (3.7.4.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\ek672\appdata\local\continuum\anaconda3\lib\site-packages (from importlib-metadata; python_version < "3.8"->jsonschema!=2.5.0,>=2.4->nbformat->notebook->jupyter->SWAMPE==0.0.19) (3.1.0)
# Installing collected packages: SWAMPE
#   Attempting uninstall: SWAMPE
#     Found existing installation: SWAMPE 0.0.17
#     Uninstalling SWAMPE-0.0.17:
#       Successfully uninstalled SWAMPE-0.0.17
# Successfully installed SWAMPE-0.0.19
# Note: you may need to restart the kernel to use updated packages.

# %%
import SWAMPE

# %% [markdown]
# First, let's specify some key physical inputs:

# %%
# planetary radius a in meters

a=8.2*10**(7) 

# planetary rotation rate omega in radians/s

omega=3.2*10**(-5)

# the reference geopotential height, m^2/s^2

Phibar=4*(10**6)

# %% [markdown]
# Now let's specify the timestep and the number of timesteps:

# %%
#timestep length in seconds

dt=30

#number of timesteps for the simulation

tmax=10

# %% [markdown]
# We will also specify the spectral resolution M.

# %%
M=42

# %% [markdown]
# Let's specify forcing parameters. The forcing strength is controlled via DPhieq. ## explain what DPhiEq is
#
# We will need timescales radiative timescale of one day and a drag timescale of ten days:

# %%
taurad=3600*24
taudrag=10*3600*24

DPhieq=Phibar

# %% [markdown]
# Now, we can use SWAMP-E to run the simulation. Note that a 2D model like SWAMP-E will need a few hundred time steps to spin up, so with a real-world example, we recommend running the model using a script rather than a Jupyter notebook.

# %% [markdown]
# Now we will specify planet type
#
# ## MOVE THIS

# %%
test=10

# %%
SWAMPE.model.run_model(M,dt,tmax,Phibar, omega, a, test, taurad=taurad, taudrag=taudrag, DPhieq=Phibar, plotflag=True, plotfreq=5,saveflag=False,verbose=False)
# Out:
# c:\Users\ek672\AppData\Local\Continuum\anaconda3\lib\site-packages\SWAMPE\plotting.py:123: UserWarning: The following kwargs were not used by contour: 'style'
#   CS = plt.contourf(X, Y, (Phi), levels=levels, cmap=colormap, extend='both',style='sci')

# %%
SWAMPE.run_model(M,dt,tmax,Phibar, omega, a, test, taurad=taurad, taudrag=taudrag, DPhieq=Phibar, plotflag=1, plotfreq=5,saveflag=0,verbose=False)
# Out:
# c:\Users\ek672\AppData\Local\Continuum\anaconda3\lib\site-packages\SWAMPE\plotting.py:123: UserWarning: The following kwargs were not used by contour: 'style'
#   CS = plt.contourf(X, Y, (Phi), levels=levels, cmap=colormap, extend='both',style='sci')

# %%
#SWAMPE.run_model(M,dt,tmax,Phibar, omega, a, test, taurad=taurad, taudrag=taudrag, DPhieq=Phibar, plotflag=0, plotfreq=5,saveflag=0)
SWAMPE.main_function.main(M,dt,tmax,Phibar, omega, a, test, taurad=taurad, taudrag=taudrag, DPhieq=Phibar, plotflag=0, plotfreq=5,saveflag=0)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-19e87d9ff47e> in <module>
#       1 #SWAMPE.run_model(M,dt,tmax,Phibar, omega, a, test, taurad=taurad, taudrag=taudrag, DPhieq=Phibar, plotflag=0, plotfreq=5,saveflag=0)
# ----> 2 SWAMPE.main_function.main(M,dt,tmax,Phibar, omega, a, test, taurad=taurad, taudrag=taudrag, DPhieq=Phibar, plotflag=0, plotfreq=5,saveflag=0)
#
# AttributeError: module 'SWAMPE' has no attribute 'main_function'

# %% [markdown]
# We can specify whether we want to see plots as the simulation is conducted and control the frequency of output.

# %% [markdown]
# ## insert images here of end product of simulations for different timescales

# %% [markdown]
# ## Saving the data

# %% [markdown]
# We can specify whether to save the data using saveflag. We can also specify savefrequency. The data will be stored in the format variable-timestamp, where timestamp can be specified in seconds, minutes, or hours, depending on simulation length.

# %% [markdown]
# We can also specify whether we want to save the data by passing an optional argument to the main function:

# %%
"custompath=None"  

"custompath=C:/your/Path/here"
# Out:
# 'custompath=C:/your/Path/here'

# %% [markdown]
# Let's save some data

# %% [markdown]
# ### Continuation

# %% [markdown]
# We can also start the simulation from any suitable initial condition. Let's restart the simulation from previously saved data.
