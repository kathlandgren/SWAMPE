# %% [markdown]
# # Tutorial

# %% [markdown]
# In this tutorial, we will explore how to use SWAMP-E to simulate planetary atmospheres.

# %%
import numpy

# %%
# %pip install -i https://test.pypi.org/simple/ SWAMPE==0.0.45
# Out:
# Looking in indexes: https://test.pypi.org/simple/
# Requirement already satisfied: SWAMPE==0.0.45 in c:\users\ek672\appdata\local\continuum\anaconda3\lib\site-packages (0.0.45)
# Requirement already satisfied: astropy in c:\users\ek672\appdata\local\continuum\anaconda3\lib\site-packages (from SWAMPE==0.0.45) (4.0.1.post1)
# Requirement already satisfied: matplotlib in c:\users\ek672\appdata\local\continuum\anaconda3\lib\site-packages (from SWAMPE==0.0.45) (3.5.2)
# Requirement already satisfied: imageio in c:\users\ek672\appdata\local\continuum\anaconda3\lib\site-packages (from SWAMPE==0.0.45) (2.8.0)
# Requirement already satisfied: numpy in c:\users\ek672\appdata\local\continuum\anaconda3\lib\site-packages (from SWAMPE==0.0.45) (1.19.2)
# Requirement already satisfied: jupyter in c:\users\ek672\appdata\local\continuum\anaconda3\lib\site-packages (from SWAMPE==0.0.45) (1.0.0)
# Requirement already satisfied: pandas in c:\users\ek672\appdata\local\continuum\anaconda3\lib\site-packages (from SWAMPE==0.0.45) (1.0.3)
# Requirement already satisfied: scipy in c:\users\ek672\appdata\local\continuum\anaconda3\lib\site-packages (from SWAMPE==0.0.45) (1.4.1)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\ek672\appdata\local\continuum\anaconda3\lib\site-packages (from matplotlib->SWAMPE==0.0.45) (2.4.7)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\ek672\appdata\local\continuum\anaconda3\lib\site-packages (from matplotlib->SWAMPE==0.0.45) (7.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ek672\appdata\local\continuum\anaconda3\lib\site-packages (from matplotlib->SWAMPE==0.0.45) (2.8.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ek672\appdata\local\continuum\anaconda3\lib\site-packages (from matplotlib->SWAMPE==0.0.45) (4.33.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\ek672\appdata\local\continuum\anaconda3\lib\site-packages (from matplotlib->SWAMPE==0.0.45) (20.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\ek672\appdata\local\continuum\anaconda3\lib\site-packages (from matplotlib->SWAMPE==0.0.45) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\ek672\appdata\local\continuum\anaconda3\lib\site-packages (from matplotlib->SWAMPE==0.0.45) (1.2.0)
# Requirement already satisfied: notebook in c:\users\ek672\appdata\local\continuum\anaconda3\lib\site-packages (from jupyter->SWAMPE==0.0.45) (6.0.3)
# Requirement already satisfied: nbconvert in c:\users\ek672\appdata\local\continuum\anaconda3\lib\site-packages (from jupyter->SWAMPE==0.0.45) (5.6.1)
# Requirement already satisfied: ipywidgets in c:\users\ek672\appdata\local\continuum\anaconda3\lib\site-packages (from jupyter->SWAMPE==0.0.45) (7.5.1)
# Requirement already satisfied: qtconsole in c:\users\ek672\appdata\local\continuum\anaconda3\lib\site-packages (from jupyter->SWAMPE==0.0.45) (4.7.4)
# Requirement already satisfied: jupyter-console in c:\users\ek672\appdata\local\continuum\anaconda3\lib\site-packages (from jupyter->SWAMPE==0.0.45) (6.1.0)
# Requirement already satisfied: ipykernel in c:\users\ek672\appdata\local\continuum\anaconda3\lib\site-packages (from jupyter->SWAMPE==0.0.45) (5.1.4)
# Requirement already satisfied: pytz>=2017.2 in c:\users\ek672\appdata\local\continuum\anaconda3\lib\site-packages (from pandas->SWAMPE==0.0.45) (2020.1)
# Requirement already satisfied: six>=1.5 in c:\users\ek672\appdata\local\continuum\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->SWAMPE==0.0.45) (1.14.0)
# Requirement already satisfied: terminado>=0.8.1 in c:\users\ek672\appdata\local\continuum\anaconda3\lib\site-packages (from notebook->jupyter->SWAMPE==0.0.45) (0.8.3)
# Requirement already satisfied: Send2Trash in c:\users\ek672\appdata\local\continuum\anaconda3\lib\site-packages (from notebook->jupyter->SWAMPE==0.0.45) (1.5.0)
# Requirement already satisfied: ipython-genutils in c:\users\ek672\appdata\local\continuum\anaconda3\lib\site-packages (from notebook->jupyter->SWAMPE==0.0.45) (0.2.0)
# Requirement already satisfied: traitlets>=4.2.1 in c:\users\ek672\appdata\local\continuum\anaconda3\lib\site-packages (from notebook->jupyter->SWAMPE==0.0.45) (4.3.3)
# Requirement already satisfied: jupyter-client>=5.3.4 in c:\users\ek672\appdata\local\continuum\anaconda3\lib\site-packages (from notebook->jupyter->SWAMPE==0.0.45) (6.1.3)
# Requirement already satisfied: nbformat in c:\users\ek672\appdata\local\continuum\anaconda3\lib\site-packages (from notebook->jupyter->SWAMPE==0.0.45) (5.0.6)
# Requirement already satisfied: prometheus-client in c:\users\ek672\appdata\local\continuum\anaconda3\lib\site-packages (from notebook->jupyter->SWAMPE==0.0.45) (0.7.1)
# Requirement already satisfied: jinja2 in c:\users\ek672\appdata\local\continuum\anaconda3\lib\site-packages (from notebook->jupyter->SWAMPE==0.0.45) (2.11.2)
# Requirement already satisfied: pyzmq>=17 in c:\users\ek672\appdata\local\continuum\anaconda3\lib\site-packages (from notebook->jupyter->SWAMPE==0.0.45) (18.1.1)
# Requirement already satisfied: jupyter-core>=4.6.1 in c:\users\ek672\appdata\local\continuum\anaconda3\lib\site-packages (from notebook->jupyter->SWAMPE==0.0.45) (4.6.3)
# Requirement already satisfied: tornado>=5.0 in c:\users\ek672\appdata\local\continuum\anaconda3\lib\site-packages (from notebook->jupyter->SWAMPE==0.0.45) (6.0.4)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\ek672\appdata\local\continuum\anaconda3\lib\site-packages (from nbconvert->jupyter->SWAMPE==0.0.45) (0.3)
# Requirement already satisfied: defusedxml in c:\users\ek672\appdata\local\continuum\anaconda3\lib\site-packages (from nbconvert->jupyter->SWAMPE==0.0.45) (0.6.0)
# Requirement already satisfied: testpath in c:\users\ek672\appdata\local\continuum\anaconda3\lib\site-packages (from nbconvert->jupyter->SWAMPE==0.0.45) (0.4.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\ek672\appdata\local\continuum\anaconda3\lib\site-packages (from nbconvert->jupyter->SWAMPE==0.0.45) (1.4.2)
# Requirement already satisfied: bleach in c:\users\ek672\appdata\local\continuum\anaconda3\lib\site-packages (from nbconvert->jupyter->SWAMPE==0.0.45) (3.1.4)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\ek672\appdata\local\continuum\anaconda3\lib\site-packages (from nbconvert->jupyter->SWAMPE==0.0.45) (0.8.4)
# Requirement already satisfied: pygments in c:\users\ek672\appdata\local\continuum\anaconda3\lib\site-packages (from nbconvert->jupyter->SWAMPE==0.0.45) (2.6.1)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\ek672\appdata\local\continuum\anaconda3\lib\site-packages (from ipywidgets->jupyter->SWAMPE==0.0.45) (3.5.1)
# Requirement already satisfied: ipython>=4.0.0; python_version >= "3.3" in c:\users\ek672\appdata\local\continuum\anaconda3\lib\site-packages (from ipywidgets->jupyter->SWAMPE==0.0.45) (7.13.0)
# Requirement already satisfied: qtpy in c:\users\ek672\appdata\local\continuum\anaconda3\lib\site-packages (from qtconsole->jupyter->SWAMPE==0.0.45) (1.9.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\ek672\appdata\local\continuum\anaconda3\lib\site-packages (from jupyter-console->jupyter->SWAMPE==0.0.45) (3.0.5)
# Requirement already satisfied: decorator in c:\users\ek672\appdata\local\continuum\anaconda3\lib\site-packages (from traitlets>=4.2.1->notebook->jupyter->SWAMPE==0.0.45) (4.4.2)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\users\ek672\appdata\local\continuum\anaconda3\lib\site-packages (from nbformat->notebook->jupyter->SWAMPE==0.0.45) (3.2.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\ek672\appdata\local\continuum\anaconda3\lib\site-packages (from jinja2->notebook->jupyter->SWAMPE==0.0.45) (1.1.1)
# Requirement already satisfied: pywin32>=1.0; sys_platform == "win32" in c:\users\ek672\appdata\local\continuum\anaconda3\lib\site-packages (from jupyter-core>=4.6.1->notebook->jupyter->SWAMPE==0.0.45) (227)
# Requirement already satisfied: webencodings in c:\users\ek672\appdata\local\continuum\anaconda3\lib\site-packages (from bleach->nbconvert->jupyter->SWAMPE==0.0.45) (0.5.1)
# Requirement already satisfied: setuptools>=18.5 in c:\users\ek672\appdata\local\continuum\anaconda3\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets->jupyter->SWAMPE==0.0.45) (46.4.0.post20200518)
# Requirement already satisfied: backcall in c:\users\ek672\appdata\local\continuum\anaconda3\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets->jupyter->SWAMPE==0.0.45) (0.1.0)
# Requirement already satisfied: colorama; sys_platform == "win32" in c:\users\ek672\appdata\local\continuum\anaconda3\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets->jupyter->SWAMPE==0.0.45) (0.4.3)
# Requirement already satisfied: jedi>=0.10 in c:\users\ek672\appdata\local\continuum\anaconda3\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets->jupyter->SWAMPE==0.0.45) (0.15.2)
# Requirement already satisfied: pickleshare in c:\users\ek672\appdata\local\continuum\anaconda3\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets->jupyter->SWAMPE==0.0.45) (0.7.5)
# Requirement already satisfied: wcwidth in c:\users\ek672\appdata\local\continuum\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->jupyter-console->jupyter->SWAMPE==0.0.45) (0.1.9)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in c:\users\ek672\appdata\local\continuum\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->notebook->jupyter->SWAMPE==0.0.45) (4.12.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\ek672\appdata\local\continuum\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->notebook->jupyter->SWAMPE==0.0.45) (0.16.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\ek672\appdata\local\continuum\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->notebook->jupyter->SWAMPE==0.0.45) (19.3.0)
# Requirement already satisfied: parso>=0.5.2 in c:\users\ek672\appdata\local\continuum\anaconda3\lib\site-packages (from jedi>=0.10->ipython>=4.0.0; python_version >= "3.3"->ipywidgets->jupyter->SWAMPE==0.0.45) (0.5.2)
# Requirement already satisfied: zipp>=0.5 in c:\users\ek672\appdata\local\continuum\anaconda3\lib\site-packages (from importlib-metadata; python_version < "3.8"->jsonschema!=2.5.0,>=2.4->nbformat->notebook->jupyter->SWAMPE==0.0.45) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.4; python_version < "3.8" in c:\users\ek672\appdata\local\continuum\anaconda3\lib\site-packages (from importlib-metadata; python_version < "3.8"->jsonschema!=2.5.0,>=2.4->nbformat->notebook->jupyter->SWAMPE==0.0.45) (3.7.4.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import SWAMPE
# Out:
# Bad key text.latex.preview in file c:\Users\ek672\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle, line 123 ('text.latex.preview : False')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.5.2/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key mathtext.fallback_to_cm in file c:\Users\ek672\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle, line 155 ('mathtext.fallback_to_cm : True  # When True, use symbols from the Computer Modern')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.5.2/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key savefig.jpeg_quality in file c:\Users\ek672\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle, line 418 ('savefig.jpeg_quality: 95       # when a jpeg is saved, the default quality parameter.')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.5.2/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key keymap.all_axes in file c:\Users\ek672\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle, line 466 ('keymap.all_axes : a                 # enable all axes')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.5.2/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key animation.avconv_path in file c:\Users\ek672\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle, line 477 ('animation.avconv_path: avconv     # Path to avconv binary. Without full path')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.5.2/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key animation.avconv_args in file c:\Users\ek672\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle, line 479 ('animation.avconv_args:            # Additional arguments to pass to avconv')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.5.2/matplotlibrc.template
# or from the matplotlib source distribution

# %% [markdown]
# First, let's specify some key physical inputs:

# %%
# planetary radius a in meters

a=8.2*10**(7) 

# planetary rotation rate omega in radians/s

omega=3.2*10**(-5)

# the reference geopotential height, m^2/s^2

Phibar=4*(10**6)

# %% [markdown]
# Now let's specify the timestep and the number of timesteps. For stability, a reasonable timestep will range from 30 to 180 seconds, with strongly forced planets needing a shorter timestep.

# %%
#timestep length in seconds

dt=30

#number of timesteps for the simulation

tmax=10

# %% [markdown]
# We will also specify the spectral resolution M. This resolution determines the size of the resulting lat-lon grid.

# %%
M=42

# %% [markdown]
# Let's specify forcing parameters. The forcing strength is controlled via DPhieq. ## explain what DPhiEq is
#
# We will need timescales radiative timescale of one day and a drag timescale of ten days:

# %%
taurad=3600*24
taudrag=10*3600*24
DPhieq=Phibar

# %% [markdown]
# Now, we can use SWAMP-E to run the simulation.
# We can specify whether we want to see plots as the simulation is conducted and control the frequency of output using plotflag and plotfreq.

# %%
plotflag=True
plotfreq=5 #output plots every 5 time steps

# %%
SWAMPE.run_model(M,dt,tmax,Phibar, omega, a,  taurad=taurad, taudrag=taudrag, DPhieq=Phibar, plotflag=plotflag, plotfreq=plotfreq,saveflag=False,verbose=False)

# %% [markdown]
# Note that a 2D model like SWAMP-E will need a few hundred time steps to spin up, so with a real-world example, we recommend running the model using a script rather than a Jupyter notebook. Here are sample outputs for the same planetary parameters, but without drag (equivalent to $\tau_{\rm drag}=\infty$) and with $\tau_{\rm rad}$ equal to 0.1, 1, and 10 Earth days.

# %% [markdown]
# ![timescale_example-1.png](attachment:timescale_example-1.png)

# %% [markdown]
# ## Saving the data

# %% [markdown]
# Since the simulations can take a few hundred timeteps to spin up, it is helpful to save the data to be loaded later. We can specify whether to save the data using saveflag. We can also specify savefrequency. The data will be stored in the pickle format with the name 'variable-timestamp', where timestamp can be specified in seconds, minutes, or hours.

# %% [markdown]
# The saved data files will look like this:
# ```
# Phi-10
# eta-10
# delta-10
# U-10
# V-10
# ```

# %% [markdown]
# This will save the data every 120 time steps in the folder C:/your/Path/here/
# ```
# SWAMPE.run_model(..., saveflag=True, savefreq=120, custompath='C:/your/Path/here/',timeunits='minutes')
#
# ```
# For a timestep of 30 seconds, the first output will look like this, with the timestamp of sixty minutes:
# ```
# Phi-60
# eta-60
# delta-60
# U-60
# V-60
# ```

# %% [markdown]
# If no custom path is provided, SWAMPE will create a local 'data/' directory and store the data there.

# %% [markdown]
# ### Continuation

# %% [markdown]
# We can also start the simulation from any suitable initial condition. Let's save some data and restart the simulation from the saved data.

# %%
#saving the data every 5 timesteps
SWAMPE.run_model(M,dt,tmax,Phibar, omega, a,  taurad=taurad, taudrag=taudrag, DPhieq=Phibar, plotflag=False, plotfreq=plotfreq,saveflag=True,savefreq=5,verbose=False,timeunits='seconds')

# %% [markdown]
# Now we can load the saved data. Let's say we want to load the data from 150 seconds.

# %%
timestamp='150'
eta, delta, Phi, U, V =SWAMPE.continuation.load_data(str(timestamp))

# %%
N,I,J,dt,lambdas,mus,w=SWAMPE.initial_conditions.spectral_params(M)
fig=SWAMPE.plotting.quiver_geopot_plot(U,V,Phi,lambdas,mus,timestamp,sparseness=4,minlevel=None,maxlevel=None,units='seconds')

# %%
SWAMPE.run_model(M,dt,tmax,Phibar, omega, a,  taurad=taurad, taudrag=taudrag, DPhieq=Phibar, plotflag=True, plotfreq=1,saveflag=False,verbose=True,timeunits='seconds',contflag=True,contTime=150)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-59-2b12b6f29e0e> in <module>
# ----> 1 SWAMPE.run_model(M,dt,tmax,Phibar, omega, a,  taurad=taurad, taudrag=taudrag, DPhieq=Phibar, plotflag=True, plotfreq=1,saveflag=False,verbose=True,timeunits='seconds',contflag=True,contTime=150)
#
# c:\Users\ek672\AppData\Local\Continuum\anaconda3\lib\site-packages\SWAMPE\model.py in run_model(M, dt, tmax, Phibar, omega, a, test, g, forcflag, taurad, taudrag, DPhieq, a1, plotflag, plotfreq, minlevel, maxlevel, diffflag, modalflag, alpha, contflag, saveflag, expflag, savefreq, K6, custompath, contTime, timeunits, verbose)
#     329         #reset for continuation
#     330         if contflag==True:
# --> 331             t=continuation.compute_t_from_timestamp(timeunits,contTime,dt)
#     332
#     333         etam0=etamdata[0,:,:]
#
# c:\Users\ek672\AppData\Local\Continuum\anaconda3\lib\site-packages\SWAMPE\continuation.py in compute_t_from_timestamp(units, timestamp, dt)
#      96         print('Cannot parse units. Acceptable units are: hours, minutes, seconds.')
#      97
# ---> 98     return t
#      99
#     100 def save_data(timestamp,etadata, deltadata, Phidata, U,V, spinupdata,geopotdata,  custompath=None):
#
# UnboundLocalError: local variable 't' referenced before assignment
