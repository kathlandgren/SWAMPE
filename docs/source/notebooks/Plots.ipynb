# %% [markdown]
# ##  Plots
#
# In this tutorial, we will explore how to plot the simulations generated by SWAMP-E.

# %%
# %pip install -i https://test.pypi.org/simple/ SWAMPE==0.0.52
# Out:
# Looking in indexes: https://test.pypi.org/simple/
# Requirement already satisfied: SWAMPE==0.0.52 in c:\users\ek672\anaconda3\lib\site-packages (0.0.52)
# Requirement already satisfied: jupyter in c:\users\ek672\anaconda3\lib\site-packages (from SWAMPE==0.0.52) (1.0.0)
# Requirement already satisfied: scipy in c:\users\ek672\anaconda3\lib\site-packages (from SWAMPE==0.0.52) (1.5.2)
# Requirement already satisfied: numpy in c:\users\ek672\anaconda3\lib\site-packages (from SWAMPE==0.0.52) (1.19.2)
# Requirement already satisfied: imageio in c:\users\ek672\anaconda3\lib\site-packages (from SWAMPE==0.0.52) (2.9.0)
# Requirement already satisfied: matplotlib in c:\users\ek672\anaconda3\lib\site-packages (from SWAMPE==0.0.52) (3.5.2)
# Requirement already satisfied: notebook in c:\users\ek672\anaconda3\lib\site-packages (from jupyter->SWAMPE==0.0.52) (6.1.4)
# Requirement already satisfied: ipywidgets in c:\users\ek672\anaconda3\lib\site-packages (from jupyter->SWAMPE==0.0.52) (7.5.1)
# Requirement already satisfied: nbconvert in c:\users\ek672\anaconda3\lib\site-packages (from jupyter->SWAMPE==0.0.52) (6.0.7)
# Requirement already satisfied: ipykernel in c:\users\ek672\anaconda3\lib\site-packages (from jupyter->SWAMPE==0.0.52) (5.3.4)
# Requirement already satisfied: qtconsole in c:\users\ek672\anaconda3\lib\site-packages (from jupyter->SWAMPE==0.0.52) (4.7.7)
# Requirement already satisfied: jupyter-console in c:\users\ek672\anaconda3\lib\site-packages (from jupyter->SWAMPE==0.0.52) (6.2.0)
# Requirement already satisfied: pillow in c:\users\ek672\anaconda3\lib\site-packages (from imageio->SWAMPE==0.0.52) (8.0.1)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\ek672\anaconda3\lib\site-packages (from matplotlib->SWAMPE==0.0.52) (2.4.7)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ek672\anaconda3\lib\site-packages (from matplotlib->SWAMPE==0.0.52) (4.33.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ek672\anaconda3\lib\site-packages (from matplotlib->SWAMPE==0.0.52) (2.8.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\ek672\anaconda3\lib\site-packages (from matplotlib->SWAMPE==0.0.52) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\ek672\anaconda3\lib\site-packages (from matplotlib->SWAMPE==0.0.52) (1.3.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\ek672\anaconda3\lib\site-packages (from matplotlib->SWAMPE==0.0.52) (20.4)
# Requirement already satisfied: jupyter-core>=4.6.1 in c:\users\ek672\anaconda3\lib\site-packages (from notebook->jupyter->SWAMPE==0.0.52) (4.6.3)
# Requirement already satisfied: argon2-cffi in c:\users\ek672\anaconda3\lib\site-packages (from notebook->jupyter->SWAMPE==0.0.52) (20.1.0)
# Requirement already satisfied: tornado>=5.0 in c:\users\ek672\anaconda3\lib\site-packages (from notebook->jupyter->SWAMPE==0.0.52) (6.0.4)
# Requirement already satisfied: ipython-genutils in c:\users\ek672\anaconda3\lib\site-packages (from notebook->jupyter->SWAMPE==0.0.52) (0.2.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\ek672\anaconda3\lib\site-packages (from notebook->jupyter->SWAMPE==0.0.52) (0.9.1)
# Requirement already satisfied: jinja2 in c:\users\ek672\anaconda3\lib\site-packages (from notebook->jupyter->SWAMPE==0.0.52) (2.11.2)
# Requirement already satisfied: nbformat in c:\users\ek672\anaconda3\lib\site-packages (from notebook->jupyter->SWAMPE==0.0.52) (5.0.8)
# Requirement already satisfied: prometheus-client in c:\users\ek672\anaconda3\lib\site-packages (from notebook->jupyter->SWAMPE==0.0.52) (0.8.0)
# Requirement already satisfied: Send2Trash in c:\users\ek672\anaconda3\lib\site-packages (from notebook->jupyter->SWAMPE==0.0.52) (1.5.0)
# Requirement already satisfied: pyzmq>=17 in c:\users\ek672\anaconda3\lib\site-packages (from notebook->jupyter->SWAMPE==0.0.52) (19.0.2)
# Requirement already satisfied: traitlets>=4.2.1 in c:\users\ek672\anaconda3\lib\site-packages (from notebook->jupyter->SWAMPE==0.0.52) (5.0.5)Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: jupyter-client>=5.3.4 in c:\users\ek672\anaconda3\lib\site-packages (from notebook->jupyter->SWAMPE==0.0.52) (6.1.7)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\ek672\anaconda3\lib\site-packages (from ipywidgets->jupyter->SWAMPE==0.0.52) (3.5.1)
# Requirement already satisfied: ipython>=4.0.0; python_version >= "3.3" in c:\users\ek672\anaconda3\lib\site-packages (from ipywidgets->jupyter->SWAMPE==0.0.52) (7.19.0)
# Requirement already satisfied: testpath in c:\users\ek672\anaconda3\lib\site-packages (from nbconvert->jupyter->SWAMPE==0.0.52) (0.4.4)
# Requirement already satisfied: jupyterlab-pygments in c:\users\ek672\anaconda3\lib\site-packages (from nbconvert->jupyter->SWAMPE==0.0.52) (0.1.2)
# Requirement already satisfied: pygments>=2.4.1 in c:\users\ek672\anaconda3\lib\site-packages (from nbconvert->jupyter->SWAMPE==0.0.52) (2.7.2)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\ek672\anaconda3\lib\site-packages (from nbconvert->jupyter->SWAMPE==0.0.52) (0.5.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\ek672\anaconda3\lib\site-packages (from nbconvert->jupyter->SWAMPE==0.0.52) (0.8.4)
# Requirement already satisfied: defusedxml in c:\users\ek672\anaconda3\lib\site-packages (from nbconvert->jupyter->SWAMPE==0.0.52) (0.6.0)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\ek672\anaconda3\lib\site-packages (from nbconvert->jupyter->SWAMPE==0.0.52) (0.3)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\ek672\anaconda3\lib\site-packages (from nbconvert->jupyter->SWAMPE==0.0.52) (1.4.3)
# Requirement already satisfied: bleach in c:\users\ek672\anaconda3\lib\site-packages (from nbconvert->jupyter->SWAMPE==0.0.52) (3.2.1)
# Requirement already satisfied: qtpy in c:\users\ek672\anaconda3\lib\site-packages (from qtconsole->jupyter->SWAMPE==0.0.52) (1.9.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\ek672\anaconda3\lib\site-packages (from jupyter-console->jupyter->SWAMPE==0.0.52) (3.0.8)
# Requirement already satisfied: six>=1.5 in c:\users\ek672\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->SWAMPE==0.0.52) (1.15.0)
# Requirement already satisfied: pywin32>=1.0; sys_platform == "win32" in c:\users\ek672\anaconda3\lib\site-packages (from jupyter-core>=4.6.1->notebook->jupyter->SWAMPE==0.0.52) (227)
# Requirement already satisfied: cffi>=1.0.0 in c:\users\ek672\anaconda3\lib\site-packages (from argon2-cffi->notebook->jupyter->SWAMPE==0.0.52) (1.14.3)
# Requirement already satisfied: pywinpty>=0.5 in c:\users\ek672\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook->jupyter->SWAMPE==0.0.52) (0.5.7)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\ek672\anaconda3\lib\site-packages (from jinja2->notebook->jupyter->SWAMPE==0.0.52) (1.1.1)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\users\ek672\anaconda3\lib\site-packages (from nbformat->notebook->jupyter->SWAMPE==0.0.52) (3.2.0)
#
# Requirement already satisfied: setuptools>=18.5 in c:\users\ek672\anaconda3\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets->jupyter->SWAMPE==0.0.52) (50.3.1.post20201107)
# Requirement already satisfied: colorama; sys_platform == "win32" in c:\users\ek672\anaconda3\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets->jupyter->SWAMPE==0.0.52) (0.4.4)
# Requirement already satisfied: pickleshare in c:\users\ek672\anaconda3\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets->jupyter->SWAMPE==0.0.52) (0.7.5)
# Requirement already satisfied: jedi>=0.10 in c:\users\ek672\anaconda3\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets->jupyter->SWAMPE==0.0.52) (0.17.1)
# Requirement already satisfied: decorator in c:\users\ek672\anaconda3\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets->jupyter->SWAMPE==0.0.52) (4.4.2)
# Requirement already satisfied: backcall in c:\users\ek672\anaconda3\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets->jupyter->SWAMPE==0.0.52) (0.2.0)
# Requirement already satisfied: nest-asyncio in c:\users\ek672\anaconda3\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->jupyter->SWAMPE==0.0.52) (1.4.2)
# Requirement already satisfied: async-generator in c:\users\ek672\anaconda3\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->jupyter->SWAMPE==0.0.52) (1.10)
# Requirement already satisfied: webencodings in c:\users\ek672\anaconda3\lib\site-packages (from bleach->nbconvert->jupyter->SWAMPE==0.0.52) (0.5.1)
# Requirement already satisfied: wcwidth in c:\users\ek672\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->jupyter-console->jupyter->SWAMPE==0.0.52) (0.2.5)
# Requirement already satisfied: pycparser in c:\users\ek672\anaconda3\lib\site-packages (from cffi>=1.0.0->argon2-cffi->notebook->jupyter->SWAMPE==0.0.52) (2.20)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\ek672\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->notebook->jupyter->SWAMPE==0.0.52) (20.3.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\ek672\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->notebook->jupyter->SWAMPE==0.0.52) (0.17.3)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in c:\users\ek672\anaconda3\lib\site-packages (from jedi>=0.10->ipython>=4.0.0; python_version >= "3.3"->ipywidgets->jupyter->SWAMPE==0.0.52) (0.7.0)

# %%
import os
import numpy as np
from matplotlib import cm
import matplotlib.pyplot as plt
import SWAMPE

# %% [markdown]
# Let's load the reference data. **Note that the path to the reference data may change depending on where the notebook is installed.**

# %%
# load  reference data
data_dir1 = os.path.abspath('../../../SWAMPE/reference_data/HJ_taurad_100/')+'\\'
timestamp1=710
eta1, delta1, Phi1, U1, V1 =SWAMPE.continuation.load_data(timestamp1,custompath=data_dir1)
data_dir2 = os.path.abspath('../../../SWAMPE/reference_data/HJ_taurad_0p1/')+'\\'
timestamp2=650
eta2, delta2, Phi2, U2, V2 =SWAMPE.continuation.load_data(timestamp2,custompath=data_dir2)

#generate the latitudes and longitude of matching resolution
M=42
N,I,J,dt,lambdas,mus,w=SWAMPE.initial_conditions.spectral_params(M)

# %% [markdown]
# ### Plotting the geopotential plot with a wind vector field

# %%
# plot the geopotential field with the overlayed wind field

fig1=SWAMPE.plotting.quiver_geopot_plot(U1,V1,Phi1,lambdas,mus,timestamp1)
fig2=SWAMPE.plotting.quiver_geopot_plot(U2,V2,Phi2,lambdas,mus,timestamp2)

# %% [markdown]
# We can change the limits of the colorbar. This can be useful for comparing the outputs of multiple simulations.

# %%
#change min/maxlevel
Phibar=4*10**6
fig1=SWAMPE.plotting.quiver_geopot_plot(U1,V1,Phi1,lambdas,mus,timestamp1,minlevel=10**4,maxlevel=3.8*10**6)
fig2=SWAMPE.plotting.quiver_geopot_plot(U2,V2,Phi2,lambdas,mus,timestamp2,minlevel=10**4,maxlevel=3.8*10**6)

# %%
#change colormap
colormap=cm.viridis
fig=SWAMPE.plotting.quiver_geopot_plot(U2,V2,Phi2,lambdas,mus,timestamp2,colormap=colormap)

# %% [markdown]
# We can also change the density of the wind vector field using sparseness.

# %%
#change sparseness
sparsenessvec=[2,4,6,8]
for i in range(len(sparsenessvec)):
    fig=SWAMPE.plotting.quiver_geopot_plot(U2,V2,Phi2,lambdas,mus,timestamp2,sparseness=sparsenessvec[i])

# %% [markdown]
# We can also save the figure. By default, SWAMPE will create a "plots" directory in the current folder.
# You can also provide a custom path using the optional argument "custompath".

# %%
#save figure tutorial

fig=SWAMPE.plotting.quiver_geopot_plot(U2,V2,Phi2,lambdas,mus,timestamp2,savemyfig=True,filename='geopotfig.pdf')

# %% [markdown]
# ### Plotting mean-zonal winds
#
# Now let's plot mean zonal winds:

# %%
# plot mean zonal winds
fig1=SWAMPE.plotting.mean_zonal_wind_plot(U1,mus,timestamp1)
plt.show()
fig2=SWAMPE.plotting.mean_zonal_wind_plot(U2,mus,timestamp2,color='purple',customtitle='Mean zonal winds for a hot Jupiter simulation')

# %% [markdown]
# These plots can also be saved similarly to the quiver geopotential plots using "savemyfig".

# %% [markdown]
# ### Plotting RMS winds during spinup
#
# GCM simulations can take a while to run. SWAMPE can save spin-up data, specifically RMS wind data as well as the minimum and maximum geopotential.

# %%
#load RMS winds
data_dir_spinup = os.path.abspath('../../../SWAMPE/reference_data/spinup_data/')+'\\'
spinup_winds=SWAMPE.continuation.read_pickle('spinup-winds',custompath=data_dir_spinup)
spinup_geopot=SWAMPE.continuation.read_pickle('spinup-geopot',custompath=data_dir_spinup)

# %%
# plot RMS winds
SWAMPE.plotting.spinup_plot(spinup_winds,30)
#plot minimal and maximal geopotential
SWAMPE.plotting.spinup_plot(spinup_geopot,30,customlegend=['min $\Phi$','max $\Phi$'],customtitle='Minimal and maximal $\Phi$')

# %% [markdown]
# ### Creating gifs

# %% [markdown]
# While many simulations converge to a constant steady-state, in many settings, oscillations are present. In these circumstances, it can be helpful to combine several snapshots into a gif.

# %%
## load reference data -- run test 1?

# %%
import imageio
## make a geopotential gif
num_snapshots=11
timestamps=np.zeros(num_snapshots)

Phidata=np.zeros((num_snapshots,J,I))
Udata=np.zeros((num_snapshots,J,I))
Vdata=np.zeros((num_snapshots,J,I))

#load data
data_dir3 = os.path.abspath('../../../SWAMPE/reference_data/SN_for_gif/')+'\\'


for i in range(num_snapshots):      
    timestamp=int(2500+10*i)
    timestamps[i]=timestamp
    eta, delta, Phi, U, V =SWAMPE.continuation.load_data(timestamp,custompath=data_dir3)
    Phidata[i,:,:]=Phi
    Udata[i,:,:]=U
    Vdata[i,:,:]=V

# %% [markdown]
# To generate a gif, we run the following code:
#
# ```
# SWAMPE.plotting.write_quiver_gif(lambdas,mus,Phidata,Udata,Vdata,timestamps,'testgif.gif',sparseness=4,frms=5)
# ```
#
# The resulting gif should look like this:

# %% [markdown]
# ![Sample SWAMPE gif](https://github.com/kathlandgren/SWAMPE/blob/main/docs/_static/testgif.gif?raw=true)
